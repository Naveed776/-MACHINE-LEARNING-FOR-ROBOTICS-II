# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 1. Reading the Data using Pandas

# %%
oData = pd.read_csv('dataset2.csv')
print('Shape of Data: ', oData.shape)
oData.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 oData = pd.read_csv('dataset2.csv')
#       2 print('Shape of Data: ', oData.shape)
#       3 oData.head()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dataset2.csv'

# %%
oData = oData.drop(columns='date')
oData.head()

# %%
oData.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 oData.info()
#
# NameError: name 'oData' is not defined

# %%
oData.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 oData.describe()
#
# NameError: name 'oData' is not defined

# %% [markdown]
# Copy the dataset into another, and replace integer label by string

# %%
nData = oData.copy() 

nData['Occupancy'] = nData.Occupancy.replace({0: 'Empty', 1:'Occupied'}).astype('object')

nDataEmpty = nData[nData['Occupancy'] == 'Empty']
nDataOccupied = nData[nData['Occupancy'] == 'Occupied']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 nData = oData.copy()
#       3 nData['Occupancy'] = nData.Occupancy.replace({0: 'Empty', 1:'Occupied'}).astype('object')
#       5 nDataEmpty = nData[nData['Occupancy'] == 'Empty']
#
# NameError: name 'oData' is not defined

# %%
nData.head()
# Out:
#    Temperature  Humidity       Light         CO2  HumidityRatio Occupancy
# 0      23.7000    26.272  585.200000  749.200000       0.004764  Occupied
# 1      23.7180    26.290  578.400000  760.400000       0.004773  Occupied
# 2      23.7300    26.230  572.666667  769.666667       0.004765  Occupied
# 3      23.7225    26.125  493.750000  774.750000       0.004744  Occupied
# 4      23.7540    26.200  488.600000  779.000000       0.004767  Occupied

# %% [markdown]
# ## 2. Data Analysis

# %% [markdown]
# #### Show to Ratio of Occupancy

# %%
colors=('#453CC9','#22AFF1')
explode=[0,0.1]
nData['Occupancy'].value_counts().plot(kind='pie', shadow=True, explode=explode, colors=colors, autopct='%.2f',figsize=(8,6))

plt.title('Ratio of Occupancy')
plt.show()

# %% [markdown]
# ### a. Correlation between the variables

# %%
plt.subplots(figsize=(8,4))
plt.title('Correlation between variables')
sns.heatmap(oData.corr(), annot=True, cmap='YlGnBu')
# Out:
# <AxesSubplot:title={'center':'Correlation between variables'}>

# %% [markdown]
# See the relation of Occupancy with other variables.
# We can see that, Light (0.93) is highly correlated with occupancy (label)

# %% [markdown]
# ## b. Overlap the features with/without Occupancy

# %% [markdown]
# ### i. Temprature

# %% [markdown]
# ##### a. Graph: All Temperature

# %%
plt.figure(figsize=(8,6))
plt.title('Temperature of All Rooms')
ax = plt.hist(nData['Temperature'], bins=50, density=False)
plt.xlabel('Temperature All Customers')
# Out:
# Text(0.5, 0, 'Temperature All Customers')

# %% [markdown]
# ##### b. Graph: Temperature When Room Occupied/Empty

# %%
plt.figure(figsize=(8,6))
plt.title('Temprature of Rooms (divided)')

plt.hist(nDataEmpty['Temperature'], bins=50, density=False)
plt.hist(nDataOccupied['Temperature'], bins=50, density=False)

plt.xlabel('Temperatures Rooms')
# Out:
# Text(0.5, 0, 'Temperatures Rooms')

# %% [markdown]
# ##### c. Graph: Overlapped Temperature Data When Room Occupied/Empty

# %%
plt.figure(figsize=(8,6))
sns.distplot(nDataEmpty['Temperature'], label='Empty')
sns.distplot(nDataOccupied['Temperature'], label='Occupied')
plt.legend()

# %% [markdown]
# ### ii. Humidity

# %% [markdown]
# ##### a. Graph: All Humidity

# %%
plt.figure(figsize=(8,6))
plt.title('Humidity of All Rooms')
ax = plt.hist(nData['Humidity'], bins=50, density=False)
plt.xlabel('Humidity All Customers')
# Out:
# Text(0.5, 0, 'Humidity All Customers')

# %% [markdown]
# ##### b. Graph: Humidity When Room Occupied/Empty

# %%
plt.figure(figsize=(8,6))
plt.title('Humidity of Rooms (divided)')

plt.hist(nDataEmpty['Humidity'], bins=50, density=False)
plt.hist(nDataOccupied['Humidity'], bins=50, density=False)

plt.xlabel('Humidity Rooms')
# Out:
# Text(0.5, 0, 'Humidity Rooms')

# %% [markdown]
# ##### c. Graph: Overlapped Humidity Data When Room Occupied/Empty

# %%
plt.figure(figsize=(8,6))
sns.distplot(nDataEmpty['Humidity'], label='Empty')
sns.distplot(nDataOccupied['Humidity'], label='Occupied')
plt.legend()

# %% [markdown]
# ### iii. Light

# %% [markdown]
# ##### a. Graph: All Light's Data

# %%
plt.figure(figsize=(8,6))
plt.title('Light of All Rooms')
ax = plt.hist(nData['Light'], bins=50, density=False)
plt.xlabel('Light All Customers')
# Out:
# Text(0.5, 0, 'Light All Customers')

# %% [markdown]
# ##### b. Graph: Light When Room Occupied/Empty

# %%
plt.figure(figsize=(8,6))
plt.title('Light of Rooms (divided)')

plt.hist(nDataEmpty['Light'], bins=50, density=False)
plt.hist(nDataOccupied['Light'], bins=50, density=False)

plt.xlabel('Light Rooms')
# Out:
# Text(0.5, 0, 'Light Rooms')

# %% [markdown]
# ##### c. Graph: Overlapped Light Data When Room Occupied/Empty

# %%
plt.figure(figsize=(8,6))
sns.distplot(nDataEmpty['Light'], label='Empty')
sns.distplot(nDataOccupied['Light'], label='Occupied')
plt.legend()

# %% [markdown]
# As we can see that light is highly dependent variable

# %% [markdown]
# ### iv. CO2

# %% [markdown]
# ##### a. Graph: All CO'2 Data

# %%
plt.figure(figsize=(8,6))
plt.title('CO2 of All Rooms')
ax = plt.hist(nData['CO2'], bins=50, density=False)
plt.xlabel('CO2 All Customers')
# Out:
# Text(0.5, 0, 'CO2 All Customers')

# %% [markdown]
# ##### b. Graph: CO2 When Room Occupied/Empty

# %%
plt.figure(figsize=(8,6))
plt.title('CO2 of Rooms (divided)')

plt.hist(nDataEmpty['CO2'], bins=50, density=False)
plt.hist(nDataOccupied['CO2'], bins=50, density=False)
plt.xlabel('CO2 Rooms')
# Out:
# Text(0.5, 0, 'CO2 Rooms')

# %% [markdown]
# ##### c. Graph: Overlapped CO2 Data When Room Occupied/Empty

# %%
plt.figure(figsize=(8,6))
sns.distplot(nDataEmpty['CO2'], label='Empty')
sns.distplot(nDataOccupied['CO2'], label='Occupied')
plt.legend()

# %% [markdown]
# ### v. HumidityRatio
# ##### a. Graph: All Humidity Ratio's Data

# %%
plt.figure(figsize=(8,6))
plt.title('Humidity Ratio of All Rooms')
ax = plt.hist(nData['HumidityRatio'], bins=50, density=False)
plt.xlabel('Humidity Ratio All Customers')
# Out:
# Text(0.5, 0, 'Humidity Ratio All Customers')

# %% [markdown]
# ##### b. Graph: Humidity Ratio When Room Occupied/Empty

# %%
plt.figure(figsize=(8,6))
plt.title('Humidity Ratio of Rooms (divided)')

plt.hist(nDataEmpty['HumidityRatio'], bins=50, density=False)
plt.hist(nDataOccupied['HumidityRatio'], bins=50, density=False)
plt.xlabel('HumidityRatio Rooms')
# Out:
# Text(0.5, 0, 'HumidityRatio Rooms')

# %% [markdown]
# ##### c. Graph: Overlapped Humidity Ratio Data When Room Occupied/Empty

# %%
plt.figure(figsize=(8,6))
sns.distplot(nDataEmpty['HumidityRatio'], label='Empty')
sns.distplot(nDataOccupied['HumidityRatio'], label='Occupied')
plt.legend()

# %% [markdown]
# ## 3. Data Pre-Processing

# %% [markdown]
# ### a. Check the Outliers

# %%
oData.describe()
# Out:
#        Temperature     Humidity        Light          CO2  HumidityRatio  \
# count  2665.000000  2665.000000  2665.000000  2665.000000    2665.000000
# mean     21.433876    25.353937   193.227556   717.906470       0.004027
# std       1.028024     2.436842   250.210906   292.681718       0.000611
# min      20.200000    22.100000     0.000000   427.500000       0.003303
# 25%      20.650000    23.260000     0.000000   466.000000       0.003529
# 50%      20.890000    25.000000     0.000000   580.500000       0.003815
# 75%      22.356667    26.856667   442.500000   956.333333       0.004532
# max      24.408333    31.472500  1697.250000  1402.250000       0.005378
#
#          Occupancy
# count  2665.000000
# mean      0.364728
# std       0.481444
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
def plot_boxplot(data, features):
    fig, axes = plt.subplots(1, len(features))

    fig.set_figheight(10)
    fig.set_figwidth(25)
    
    plt.grid(False)
    sns.set_theme(style='whitegrid')

    index=0
    for i in features:
        b = sns.boxplot( ax=axes[index], data=data,  y=i)
        b.set_xlabel(i, fontsize=20)
        b.set_ylabel('')
        index=index+1

# %%
features = oData.drop(columns='Occupancy').columns

plot_boxplot(oData, features)

# %% [markdown]
# As you can see that light has some outliers

# %% [markdown]
# ### b. Remove Outliers

# %%
def clean_outliers(data, features):
    for feature in features:
        
        #Find min and max thresold 
        minThresold = data[feature].quantile(0.25)
        maxThresold = data[feature].quantile(0.75)   
        
        iQR = maxThresold - minThresold

        # calculate the outlier cutoff
        cutOff = 1.5 * iQR
        
        lower, upper = minThresold - cutOff, maxThresold + cutOff
        
        #Remove the outliers
        
        data = data[ (data[feature] > lower) & (data[feature] < upper) ]
    
    return data

# %%
features = oData.columns
print(features)
# Out:
# Index(['Temperature', 'Humidity', 'Light', 'CO2', 'HumidityRatio',
#        'Occupancy'],
#       dtype='object')

# %%
cData = clean_outliers(oData, features)
print("Original shape: ", oData.shape)
print("Cleaned shape: ", cData.shape)
# Out:
# Original shape:  (2665, 6)
# Cleaned shape:  (2662, 6)

# %%
features = oData.drop(columns='Occupancy').columns

plot_boxplot(cData, features)

# %% [markdown]
# ### c. Normalized DataSet for Models based on GD

# %%
import pandas as pd
from sklearn import preprocessing

x = cData.values #returns a numpy array
minMaxScaler = preprocessing.MinMaxScaler()
xScaled = minMaxScaler.fit_transform(x)
nData = pd.DataFrame(xScaled, columns=cData.columns)

print(nData.head())
# Out:
#    Temperature  Humidity     Light       CO2  HumidityRatio  Occupancy
# 0     0.831683  0.445132  0.716279  0.330033       0.704212        1.0
# 1     0.835960  0.447053  0.707956  0.341523       0.708308        1.0
# 2     0.838812  0.440651  0.700938  0.351030       0.704689        1.0
# 3     0.837030  0.429448  0.604345  0.356245       0.694383        1.0
# 4     0.844515  0.437450  0.598042  0.360605       0.705384        1.0

# %% [markdown]
# ## 4. Building Models

# %% [markdown]
# ### a. Split the dataset into Test and Train

# %%
features = cData.drop(columns='Occupancy')
target = cData['Occupancy']

nFeatures = nData.drop(columns='Occupancy')
nTarget = nData['Occupancy']

# %%
from sklearn.model_selection import train_test_split

xTrain, xTest, yTrain, yTest = train_test_split(features, target, test_size=0.2, random_state=0)
xnTrain, xnTest, ynTrain, ynTest = train_test_split(nFeatures, nTarget, test_size=0.2, random_state=0)

print(xTrain.shape)
print(xTest.shape)
print(yTrain.shape)
print(yTest.shape)
# Out:
# (2129, 5)
# (533, 5)
# (2129,)
# (533,)

# %% [markdown]
# ### b. Model Training

# %% [markdown]
# Import some libaries for evaluation of models

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score
from sklearn.metrics import f1_score, confusion_matrix, roc_auc_score

# %%
results = pd.DataFrame({'Model': [],'Accuracy Score': [], 'Recall':[], 'F1score':[]})

# %% [markdown]
# #### 1. Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

tree = DecisionTreeClassifier(max_depth=4)
tree.fit(xTrain, yTrain)

yPredict = tree.predict(xTest)

result = pd.DataFrame({"Model":['Decision Tree Classifier'],
                    "Accuracy Score": [accuracy_score(yPredict, yTest)],
                    "Recall": [recall_score(yTest, yPredict)],
                    "F1score": [f1_score(yTest, yPredict)]})

results = results.append(result)

# %% [markdown]
# ##### Confusion Matrics

# %%
pd.crosstab(yTest, yPredict, rownames=['Real Data'], colnames=['Predicted'])
# Out:
# Predicted    0    1
# Real Data
# 0          330    7
# 1            0  196

# %% [markdown]
# #### 2. Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier(n_estimators=2500, max_depth=4)
rfc.fit(xTrain, yTrain)

yPredict = rfc.predict(xTest)

result = pd.DataFrame({"Model":['Random Forest Classifier'],
                    "Accuracy Score": [accuracy_score(yPredict, yTest)],
                    "Recall": [recall_score(yTest, yPredict)],
                    "F1score": [f1_score(yTest, yPredict)]})

results = results.append(result)

# %% [markdown]
# ##### Confusion Matrics

# %%
pd.crosstab(yTest , yPredict ,rownames=['Real data'],colnames=['Predicted'])
# Out:
# Predicted    0    1
# Real data
# 0          329    8
# 1            0  196

# %% [markdown]
# #### 3. KNeighbors Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier()
knn.fit(xTrain, yTrain)

yPredict = knn.predict(xTest)

result = pd.DataFrame({"Model":['KNeighbors Classifier'],
                    "Accuracy Score": [accuracy_score(yPredict, yTest)],
                    "Recall": [recall_score(yTest, yPredict)],
                    "F1score": [f1_score(yTest, yPredict)]})

results = results.append(result)

# %% [markdown]
# ##### Confusion Matrics

# %%
pd.crosstab(yTest , yPredict ,rownames=['Real data'],colnames=['Predicted'])
# Out:
# Predicted    0    1
# Real data
# 0          333    4
# 1            4  192

# %% [markdown]
# #### 4. SVM

# %%
from sklearn.svm import SVC

svc = SVC()
svc.fit(xTrain, yTrain)

yPredict = svc.predict(xTest)

result = pd.DataFrame({"Model":['SVC'],
                    "Accuracy Score": [accuracy_score(yPredict, yTest)],
                    "Recall": [recall_score(yTest, yPredict)],
                    "F1score": [f1_score(yTest, yPredict)]})

results = results.append(result)

svc.fit(xnTrain, ynTrain)

yPredict = svc.predict(xnTest)

result = pd.DataFrame({"Model":['SVC (normalized)'],
                    "Accuracy Score": [accuracy_score(yPredict, ynTest)],
                    "Recall": [recall_score(ynTest, yPredict)],
                    "F1score": [f1_score(ynTest, yPredict)]})

results = results.append(result)

# %% [markdown]
# ##### Confusion Matrics

# %%
pd.crosstab(yTest , yPredict ,rownames=['Real data'],colnames=['Predicted'])
# Out:
# Predicted  0.0  1.0
# Real data
# 0          328    9
# 1            0  196

# %% [markdown]
# #### 5. Logisitc Regression

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()
lr.fit(xTrain, yTrain)

yPredict = lr.predict(xTest)

result = pd.DataFrame({"Model":['Logistic Regression'],
                    "Accuracy Score": [accuracy_score(yPredict, yTest)],
                    "Recall": [recall_score(yTest, yPredict)],
                    "F1score": [f1_score(yTest, yPredict)]})

results = results.append(result)


lr.fit(xnTrain, ynTrain)

yPredict = svc.predict(xnTest)

result = pd.DataFrame({"Model":['Logistic Regression (normalized)'],
                    "Accuracy Score": [accuracy_score(yPredict, ynTest)],
                    "Recall": [recall_score(ynTest, yPredict)],
                    "F1score": [f1_score(ynTest, yPredict)]})
results = results.append(result)

# %% [markdown]
# ##### Confusion Matrics

# %%
pd.crosstab(yTest , yPredict ,rownames=['Real data'],colnames=['Predicted'])
# Out:
# Predicted  0.0  1.0
# Real data
# 0          328    9
# 1            0  196

# %% [markdown]
# ### Result

# %%
results.sort_values(by='Accuracy Score', ascending=False)
# Out:
#                               Model  Accuracy Score    Recall   F1score
# 0          Decision Tree Classifier        0.986867  1.000000  0.982456
# 0          Random Forest Classifier        0.984991  1.000000  0.980000
# 0             KNeighbors Classifier        0.984991  0.979592  0.979592
# 0                               SVC        0.983114  1.000000  0.977556
# 0                  SVC (normalized)        0.983114  1.000000  0.977556
# 0               Logistic Regression        0.983114  1.000000  0.977556
# 0  Logistic Regression (normalized)        0.983114  1.000000  0.977556

# %% [markdown]
# How we see - **DecisionTreeClassifier** gives the best results

# %% [markdown]
# ## 5. Model Evaluation

# %%
from sklearn.metrics import classification_report,plot_confusion_matrix,plot_roc_curve
from sklearn.model_selection import GridSearchCV

# %%
def evaluation(yTest, yPredict):
  acc = accuracy_score(yTest , yPredict)
  rcl = recall_score(yTest,yPredict)
  f1 = f1_score(yTest,yPredict)
  aucScore = roc_auc_score(yTest,yPredict)
  precScore = precision_score(yTest,yPredict)
 

  result = {'accuracy': round(acc,3),
               'recall': round(rcl,3),
               'F1 score': round(f1,3),
               'auc score': round(aucScore,3),
               'precision': round(precScore,3) 
              }

  return print(result)

# %%
treeModel = DecisionTreeClassifier(max_depth=4)
treeModel.fit(xTrain, yTrain)

yPredict = treeModel.predict(xTest)

# %% [markdown]
# ### Find the Best Parameters for DT

# %%
params = { 
    'criterion':['gini','entropy'],
    'max_depth':range(1,10),
    'min_samples_split':range(1,10),
    'min_samples_leaf':range(1,5)
}

grid = GridSearchCV(treeModel,
                    param_grid=params,
                    cv=10,
                    verbose=1,
                    n_jobs=-1)

grid.fit(xTrain, yTrain)

print(grid.best_estimator_.get_params())
# Out:
# Fitting 10 folds for each of 648 candidates, totalling 6480 fits
# {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': 9, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'random_state': None, 'splitter': 'best'}

# %% [markdown]
# ### Train the model again with best params

# %%
treeModel2 = DecisionTreeClassifier(max_depth=7, criterion='gini',min_samples_leaf=1, min_samples_split=4, splitter= 'best')
treeModel2.fit(xTrain, yTrain)

yPredict2 = treeModel2.predict(xTest)

# %%
print(" Best evaluation parameters achieved with DecisionTree:") 
evaluation(yTest, yPredict)
evaluation(yTest, yPredict2)
# Out:
#  Best evaluation parameters achieved with DecisionTree:
# {'accuracy': 0.987, 'recall': 1.0, 'F1 score': 0.982, 'auc score': 0.99, 'precision': 0.966}
# {'accuracy': 0.987, 'recall': 0.995, 'F1 score': 0.982, 'auc score': 0.989, 'precision': 0.97}

# %% [markdown]
# Not have too much difference

# %% [markdown]
# #### Classification Report

# %%
print(classification_report(yTest, yPredict))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       337
#            1       0.97      1.00      0.98       196
#
#     accuracy                           0.99       533
#    macro avg       0.98      0.99      0.99       533
# weighted avg       0.99      0.99      0.99       533

# %% [markdown]
# #### Confusion Matrics

# %%
plot_confusion_matrix(treeModel, xTest, yTest ,cmap='YlOrBr')

# %% [markdown]
# #### ROC curve

# %%
plot_roc_curve(treeModel, xTest, yTest)

# %% [markdown]
# ## 6. Feature Importance (As we did in Correlation)

# %%
from sklearn.model_selection import cross_val_score

cvAccuracy = cross_val_score(treeModel, xTrain, yTrain, cv=5, scoring='accuracy')

print(f'Cross Validaion accuracy Scores: {cvAccuracy}')
print(f'Cross Validation accuracy Mean Score: {cvAccuracy.mean()}')
print(f'Cross Validation accuracy Standard dev: {cvAccuracy.std()}')
# Out:
# Cross Validaion accuracy Scores: [0.97887324 0.98356808 0.99295775 0.9741784  0.97647059]
# Cross Validation accuracy Mean Score: 0.9812096106048053
# Cross Validation accuracy Standard dev: 0.006647343595443003

# %% [markdown]
# ### a. Feature Importance

# %%
featureImportance = treeModel.feature_importances_
featureImportance = pd.DataFrame(featureImportance, columns=['Score'], index=features.columns)

# %%
featureImportance.sort_values(by='Score', ascending=False).style.background_gradient(cmap='OrRd')
# Out:
# <style type="text/css">
# #T_8061f_row0_col0 {
#   background-color: #7f0000;
#   color: #f1f1f1;
# }
# #T_8061f_row1_col0 {
#   background-color: #fff5e7;
#   color: #000000;
# }
# #T_8061f_row2_col0 {
#   background-color: #fff7eb;
#   color: #000000;
# }
# #T_8061f_row3_col0, #T_8061f_row4_col0 {
#   background-color: #fff7ec;
#   color: #000000;
# }
# </style>
# <table id="T_8061f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8061f_level0_col0" class="col_heading level0 col0" >Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8061f_level0_row0" class="row_heading level0 row0" >Light</th>
#       <td id="T_8061f_row0_col0" class="data row0 col0" >0.970091</td>
#     </tr>
#     <tr>
#       <th id="T_8061f_level0_row1" class="row_heading level0 row1" >HumidityRatio</th>
#       <td id="T_8061f_row1_col0" class="data row1 col0" >0.016828</td>
#     </tr>
#     <tr>
#       <th id="T_8061f_level0_row2" class="row_heading level0 row2" >Temperature</th>
#       <td id="T_8061f_row2_col0" class="data row2 col0" >0.007664</td>
#     </tr>
#     <tr>
#       <th id="T_8061f_level0_row3" class="row_heading level0 row3" >CO2</th>
#       <td id="T_8061f_row3_col0" class="data row3 col0" >0.003829</td>
#     </tr>
#     <tr>
#       <th id="T_8061f_level0_row4" class="row_heading level0 row4" >Humidity</th>
#       <td id="T_8061f_row4_col0" class="data row4 col0" >0.001589</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.figure(figsize=(13,7))
plt.title('Importance of Features')
sns.barplot( x=featureImportance.Score, y= featureImportance.index)
# Out:
# <AxesSubplot:title={'center':'Importance of Features'}, xlabel='Score'>

# %% [markdown]
# ## 7. Visualize a Decision Tree

# %%
from sklearn import tree

features = features.columns
classes = ['Empty', 'Occupied']

fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(treeModel,
               feature_names = features,
               class_names = classes,
               filled=True
              )

# %%
fig.savefig('decistion_tree.png')

# %% [markdown]
# ### Conclusion:
#
# The chosen model was **DecisionTree Classification** since it´s the most accurate, and got a perfecf accuracy.
#
# Through the analysis of feature importance, we can assume that **Light** is the most important features of classification.
